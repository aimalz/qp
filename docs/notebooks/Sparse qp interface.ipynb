# %%
import numpy as np
import os

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline

import astropy

import qp
# %config Completer.use_jedi = False

# %%
ens = qp.read('qp_test_ensemble.hdf5')
ens_red = ens[np.arange(10)]
z = ens.metadata()['xvals'][0]
P = ens_red.objdata()['yvals']
Ntot = len(P)

# %% [markdown]
# First possible usage : A trivial conversion from gaussian mixmod to same voigt bases (so gamma set to 0)

# %%
# Convert to a gaussian mixture using 301 sample points and ncomps components
ncomps = 3
xvals = np.linspace(0, 3.0, 301)
ens_m = qp.convert(ens_red, 'mixmod', xvals=xvals, ncomps=ncomps)
ens_voigt = qp.convert(ens_m, 'voigt')

# %%
key = 1
axes_m = ens_red.plot(key, xlim=(0, 0.3), label="original", marker='.')
_ = ens_m.plot(key, axes=axes_m, label="gaus")
_ = ens_voigt.plot(key, axes=axes_m, label="voigt")
leg_m = axes_m.figure.legend()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# 2 remarks :
# - the mixmod fit seems a bit unstable : https://github.com/LSSTDESC/qp/issues/28
# - the truncation at z=0 is quite interesting; this could be typical of a faint star, for which the star/galaxy separation fails but the colours still allow for a non zero redshift solution to the photoz estimation. The fact that the representaiton has a second mode distinctly distinct from 0 compared to the original pdf is a potentially serious concern

# %% [markdown]
# The next stage would be to convert the original xy representation into a sparse one, based on the orthogonal matching pursuit scheme and the Voigt basis implemented in sparse_rep

# %%
ens_sparse = qp.convert(ens_red, class_name='sparse')
# Out:
# Total Galaxies =  10
# dz =  0.0007357859336163683
# Nmu, Nsig, Nv =  [ 300 , 50 , 3 ]
# Total bases in dictionary 45000
# Nsparse (number of bases) =  20
# Creating Dictionary...
# Creating Sparse representation...
# done

# %%
key = 9
axes_m = ens_red.plot(key, xlim=(0, 0.5), label="original", color='r')
_ = ens_sparse.plot(key,axes=axes_m, label="sparse",marker='.',color='b',linewidth=0)
leg_m = axes_m.figure.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-eba68acc9841> in <module>
#       1 key = 9
#       2 axes_m = ens_red.plot(key, xlim=(0, 0.5), label="original", color='r')
# ----> 3 _ = ens_sparse.plot(key,axes=axes_m, label="sparse",marker='.',color='b',linewidth=0)
#       4 leg_m = axes_m.figure.legend()
#
# ~/lsst/codes/pipelines/photoz/qp/qp/ensemble.py in plot(self, key, **kwargs)
#     578             Which PDF or PDFs from this ensemble to plot
#     579         """
# --> 580         return self._gen_class.plot(self[key], **kwargs)
#     581
#     582     def plot_native(self, key=0, **kwargs):
#
# ~/lsst/codes/pipelines/photoz/qp/qp/ensemble.py in __getitem__(self, key)
#      62             else:
#      63                 red_data[k] = v
# ---> 64         return Ensemble(self._gen_obj.create, data=red_data)
#      65
#      66     @property
#
# ~/lsst/codes/pipelines/photoz/qp/qp/ensemble.py in __init__(self, gen_func, data)
#      30         #start_time = timeit.default_timer()
#      31         self._gen_func = gen_func
# ---> 32         self._frozen = self._gen_func(**data)
#      33         self._gen_obj = self._frozen.dist
#      34         self._gen_class = type(self._gen_obj)
#
# ~/lsst/codes/pipelines/photoz/qp/qp/pdf_gen.py in create(cls, **kwds)
#     132         keyword arguemntets provided"""
#     133         # pylint: disable=not-callable
# --> 134         obj, kwds_freeze = cls.create_gen(**kwds)
#     135         return obj(**kwds_freeze)
#     136
#
# ~/lsst/codes/pipelines/photoz/qp/qp/pdf_gen.py in create_gen(cls, **kwds)
#     358         """Create and return a `scipy.stats.rv_continuous` object using the
#     359         keyword arguemntets provided"""
# --> 360         return (cls(**kwds), dict())
#     361
#     362     def moment(self, n, *args, **kwds):
#
# TypeError: __init__() missing 2 required positional arguments: 'sparse_indices' and 'sparse_meta'

# %% [markdown]
# So this fails a bit cryptically to me....
# Another natural way to proceed would be to inherit for the interp class from qp, as in essence the sparse representation encodes an 'xy' representation into a sparse representation.

# %%
ens_voigt0 = qp.convert(ens_red, class_name='sparse2')
# Out:
# Total Galaxies =  10
# dz =  0.0007357859336163683
# Nmu, Nsig, Nv =  [ 300 , 50 , 3 ]
# Total bases in dictionary 45000
# Nsparse (number of bases) =  20
# Creating Dictionary...
# Creating Sparse representation...
# done
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-976ae419d24d> in <module>
# ----> 1 ens_voigt0 = qp.convert(ens_red, class_name='sparse2')
#
# ~/lsst/codes/pipelines/photoz/qp/qp/factory.py in convert(self, in_dist, class_name, **kwds)
#     179             raise KeyError("Class named %s does not have a extraction_method named %s" % (class_name, method))
#     180         data = extract_func(in_dist, **kwds_copy)
# --> 181         return self.create(class_name, data, method)
#     182
#     183
#
# ~/lsst/codes/pipelines/photoz/qp/qp/factory.py in create(self, class_name, data, method)
#     114         the_class = self[class_name]
#     115         ctor_func = the_class.creation_method(method)
# --> 116         return Ensemble(ctor_func, data)
#     117
#     118
#
# ~/lsst/codes/pipelines/photoz/qp/qp/ensemble.py in __init__(self, gen_func, data)
#      30         #start_time = timeit.default_timer()
#      31         self._gen_func = gen_func
# ---> 32         self._frozen = self._gen_func(**data)
#      33         self._gen_obj = self._frozen.dist
#      34         self._gen_class = type(self._gen_obj)
#
# ~/lsst/codes/pipelines/photoz/qp/qp/pdf_gen.py in create(cls, **kwds)
#     133         # pylint: disable=not-callable
#     134         obj, kwds_freeze = cls.create_gen(**kwds)
# --> 135         return obj(**kwds_freeze)
#     136
#     137     @classmethod
#
# ~/miniconda3/envs/rail/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py in __call__(self, *args, **kwds)
#     834
#     835     def __call__(self, *args, **kwds):
# --> 836         return self.freeze(*args, **kwds)
#     837     __call__.__doc__ = freeze.__doc__
#     838
#
# ~/lsst/codes/pipelines/photoz/qp/qp/pdf_gen.py in freeze(self, *args, **kwds)
#     352             The frozen distribution.
#     353         """
# --> 354         return rv_frozen_rows(self, self._shape, *args, **kwds)
#     355
#     356     @classmethod
#
# ~/lsst/codes/pipelines/photoz/qp/qp/pdf_gen.py in __init__(self, dist, shape, *args, **kwds)
#     256         if self._npdf is not None:
#     257             kwds.setdefault('row', np.expand_dims(np.arange(self._npdf).reshape(self._shape), -1))
# --> 258         super(rv_frozen_rows, self).__init__(dist, *args, **kwds)
#     259
#     260     @property
#
# ~/miniconda3/envs/rail/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py in __init__(self, dist, *args, **kwds)
#     435
#     436         # create a new instance
# --> 437         self.dist = dist.__class__(**dist._updated_ctor_param())
#     438
#     439         shapes, _, _ = self.dist._parse_args(*args, **kwds)
#
# ~/lsst/codes/pipelines/photoz/qp/qp/sparse2_pdf.py in __init__(self, sparse_indices, sparse_meta, *args, **kwargs)
#      32         norms = sciint.trapz(y.T, x)
#      33         y /= norms
# ---> 34         super(sparse2_gen, self).__init__(x, y.T, *args, **kwargs)
#      35         self._xvals = x
#      36         self._yvals = y.T
#
# TypeError: __init__() got multiple values for argument 'xvals'

# %% [markdown]
# Again a cryptic trace and failure mode..... at least to me
